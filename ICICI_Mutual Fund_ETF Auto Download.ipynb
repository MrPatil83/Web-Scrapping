# %%
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import requests
import datetime

 

links = ['https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/frmBharat22Portfolio.aspx',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=d1%2FH9hBumrcVXTMoaMA49A%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=olV71c8xGnlS5FJHI3bXBw%3d%3d',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=6uN3eBfyLNDk9eTO4ACo1A%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=Qoh6PUu0iiJDNI4gEEbzMQ%3d%3d',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=jcM5Lab%2FC59GRFz0t6eUIA%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=av50t6H%2B0gafxnRm4mJT0g%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=MgAmNZT0f5pebnQTZf2ERA%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=JYKpfDMKiMCfPVmvd30ZzA%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=1htQ8Kh9%2BMgv4WdNHKmtcg%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=i7IsRMQtzvdZ1BIWfvQ3uw%3d%3d',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=MHXc%2F3LYBw92XFj3z5XNwQ%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=NYv1iHyXAUIpLVlh777c7A%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=RIeDyjDodGyKn68PUyJ%2fjQ%3d%3d',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=%2b2Qj9h6k2SPitcxMfa7l0w%3d%3d',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=13%2FP6zmMul9MBuUFovWd%2Fw%3D%3D',
'https://arch.icicipruamc.com/AMC_WEB/APP/ASPX/ETFPortFolioDeposit.aspx?ETF=WM5Bjivf51d7L1ERzOjD9Q%3D%3D']

 

 

def download_file(links):

 

    for i, link in enumerate(links):

 

            chrome_options = Options()

 

            downloadpath = r'C:\Users\Avinash.Patil\OneDrive - Cogencis Information Services Ltd\Desktop\ICICI ETF Downloading\080923023'

 

            driver = webdriver.Chrome()

 

            url = link
            driver.get(url)

 

            driver.maximize_window()
            time.sleep(5)

 

            start_date = datetime.datetime(2023, 9, 8)
            current_date = datetime.datetime.now()

 

            current = start_date

 

            while current <= current_date:
                date_time = current.strftime('%d-%b-%Y')
                current += datetime.timedelta(days=1)
                time.sleep(3)

 

                send_date = driver.find_element(By.ID,value='ctl00_ContentPlaceHolder1_txtdatepicker')
                send_date.clear()
                send_date.send_keys(date_time)
                time.sleep(4)

 

                scheme_name = driver.find_element(By.CLASS_NAME,value='wrapHead').find_element(By.TAG_NAME,value='h1').text
                print(scheme_name)

 

                # submit button
                driver.find_element(By.CLASS_NAME,value='inputBtn').click()

 

                try:
                    time.sleep(3)
                    filename = f'icici___{i}_{date_time}__'

 

                    # excel file
                    driver.find_element(By.ID, value='ctl00_ContentPlaceHolder1_cmdExcel').click()
                    time.sleep(3)

 

                    home = os.path.expanduser('~')
                    path = os.path.join(home, downloadpath)
                    path_a = path + "/*"
                    list_of_files = glob.glob(path_a)
                    latest_file = max(list_of_files, key=os.path.getctime)
                    new_file = os.path.join(path, filename + ".xls")
                    os.rename(latest_file, new_file)
                    time.sleep(4)

 

                except:
                    print("NO DATA FOUND")
                    continue

 

download_file(links)
