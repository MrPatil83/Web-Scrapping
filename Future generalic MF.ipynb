# %%
import requests
from bs4 import BeautifulStoneSoup
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import requests
download_path=r"C:\Users\Avinash.Patil\OneDrive - Cogencis Information Services Ltd\Desktop\Futuare generalic PD (His data)"
chrome_option = Options()
chrome_option.add_experimental_option('prefs', {
                'download.default_directory': download_path,
                'download.prompt_for_download': False,
                'download.directory_upgrade': True,
                'safebrowsing.enabled': True
            })
 
driver = webdriver.Chrome(options=chrome_option)


url = "https://life.futuregenerali.in/about-us/public-disclosures"
driver.get(url)
driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div[1]/div/select").click()
time.sleep(2)
for n in range(1,16):
    # print(n)
    link=driver.find_element(By.XPATH,f"/html/body/div[1]/div[6]/div/div[1]/div/select/option[{n}]").click()
    print(link)
    time.sleep(5)
    
    # for p in range(1,6):
    #     p=str(p)
    #     a=driver.find_element(By.XPATH,f"").click()
    #     print(a)
    #     time.sleep(3)
        
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    data = soup.find('ul',{'class': 'listStyle15'}).find_all('a')
    
    for item in data:
        href = item.get('href')
        source_link = 'https://life.futuregenerali.in' + href
        print(source_link)
        
    def download_file(file_url):
        response = requests.get(file_url)
        if response.status_code == 200:
            excel_data = response.content
            local_file_path = 'downloaded_file.pdf'
            with open(local_file_path, 'wb') as file:
              file.write(excel_data)
    
        
    # driver.find_element(By.XPATH,"/html/body/pdf-viewer//viewer-toolbar//div/div[3]/viewer-download-controls//cr-icon-button").click()
# Out:
# None
# https://life.futuregenerali.in/media/eozmggbp/public-disclosure_30-june-2023-1.pdf
# https://life.futuregenerali.in/media/znwp5lbb/list-of-individual-agents-as-on-31-08-23.pdf
# None
# https://life.futuregenerali.in/media/eozmggbp/public-disclosure_30-june-2023-1.pdf
# https://life.futuregenerali.in/media/znwp5lbb/list-of-individual-agents-as-on-31-08-23.pdf
# None
# https://life.futuregenerali.in/media/0zhn5ahz/consolidated-pd_31-march-2023.pdf
# https://life.futuregenerali.in/media/f5lmb2zz/public-disclosure_december-2022.pdf
# https://life.futuregenerali.in/media/df4i12mi/public-disclosure_30-september-2022-1.pdf
# https://life.futuregenerali.in/media/zzxdydtk/public-disclosure_30-june-2022.pdf
# https://life.futuregenerali.in/media/0z5hhzcp/list-of-individual-agents-as-on-31-07-23.pdf
# None
# https://life.futuregenerali.in/media/gbhfwg0p/public-disclosure_march-2021.pdf
# https://life.futuregenerali.in/media/qzgbddwe/public-disclosure_december-2020.pdf
# ...
